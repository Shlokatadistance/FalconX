# %%
import requests
#can also use graphene for querying the data


def run_query(query):  
    headers = {'X-API-KEY': 'BQYnbUvCtd2FniXhzqMbyMajopcyIsTZ'}
    request = requests.post('https://graphql.bitquery.io/',
                            json={'query': query}, headers=headers)
    #request = requests.post('https://api.bloxy.info/dex/pair_stat?key=ACCWmH4be2fv5&format=table',json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed and return code is {}.      {}'.format(request.status_code,
                        query))

# %%
query = """
{
  ethereum(network: ethereum) {
    dexTrades(options: {limit: 1000, desc: ["block.height", "tradeIndex"]},
      protocol: {is: "Uniswap v2"}, 
      buyCurrency: {is: "0xdac17f958d2ee523a2206206994597c13d831ec7"},
      sellCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}) {
      block {
        height
        timestamp {
          iso8601
        }
      }
      transaction {
        hash
      }
      tradeIndex
      buyCurrency {
        symbol
        address
      }
      buyAmount
      sellCurrency {
        symbol
        address
      }
      sellAmount
      maker {
        address
        annotation
      }
      taker {
        address
        annotation
      }
      protocol
      smartContract {
        address {
          address
          annotation
        }
        contractType
      }
    }
  }
}
"""
result = run_query(query)  # Execute the query
print(result['data']['ethereum'])
#print ('Result - {}'.format(result))
# Out:
# {'dexTrades': [{'block': {'height': 12687442, 'timestamp': {'iso8601': '2021-06-23T01:13:05Z'}}, 'transaction': {'hash': '0xe32ca6362a052dbc3e4390cd0ba4f38dd63a24c2af5ccac245389662575dfaf6'}, 'tradeIndex': '7', 'buyCurrency': {'symbol': 'USDT', 'address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'buyAmount': 411.989535, 'sellCurrency': {'symbol': 'WETH', 'address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'}, 'sellAmount': 0.21509324653206685, 'maker': {'address': '0x0000000000007f150bd6f54c40a34d7c3d5e9f56', 'annotation': None}, 'taker': {'address': '0xdfee68a9adb981cd08699891a11cabe10f25ec44', 'annotation': None}, 'protocol': 'Uniswap v2', 'smartContract': {'address': {'address': '0x60fa657cec375e8208e23f50c4ec03167f7c6076', 'annotation': None}, 'contractType': 'DEX'}}, {'block': {'height': 12687442, 'timestamp': {'iso8601': '2021-06-23T01:13:05Z'}}, 'transaction': {'hash': '0xacd255094cf80150742d34bc2169850da41be037c612496bc7e1cde12111e9aa'}, 'tradeIndex': '21', 'buyCurrency': {'symbol': 'USDT', 'address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'buyAmount': 47993.361914, 'sellCurrency': {'symbol': 'WETH', 'address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'}, 'sellAmount': 24.318618874913867, 'maker': {'address': '0xfd3dfb524b2da40c8a6d703c62be36b5d8540626', 'annotation': None}, 'taker': {'address': '0xfd3dfb524b2da40c8a6d703c62be36b5d8540626', 'annotation': None}, 'protocol': 'Uniswap v2', 'smartContract': {'address': {'address': '0x06da0fd433c1a5d7a4faa01111c044910a184553', 'annotation': None}, 'contractType': 'DEX'}}, {'block': {'height': 12687442, 'timestamp': {'iso8601': '2021-06-23T01:13:05Z'}}, 'transaction': {'hash': '0xacd255094cf80150742d34bc2169850da41be037c612496bc7e1cde12111e9aa'}, 'tradeIndex': '11', 'buyCurrency': {'symbol': 'USDT', 'address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'buyAmount': 9598.672382, 'sellCurrency': {'symbol': 'WETH', 'address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'}, 'sellAmount': 4.855868247223764, 'maker': {'address': '0xfd3dfb524b2da40c8a6d703c62be36b5d8540626', 'annotation': None}, 'taker': {'address': '0xfd3dfb524b2da40c8a6d703c62be36b5d8540626', 'annotation': None}, 'protocol': 'Uniswap v2', 'smartContract': {'address': {'address': '0x74c99f3f5331676f6aec2756e1f39b4fc029a83e', 'annotation': None}, 'contractType': 'DEX'}}, {'block': {'height': 12687441, 'timestamp': {'iso8601': '2021-06-23T01:12:58Z'}}, 'transaction': {'hash': '0xe48576a79adfeb822a27db0a4c71e3720595dd6f44e489b8a46beca5e3d5cfcd'}, 'tradeIndex': '4', 'buyCurrency': {'symbol': 'USDT', 'address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'buyAmount': 1000.0, 'sellCurrency': {'symbol': 'WETH', 'address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'}, 'sellAmount': 0.5069166610809466, 'maker': {'address': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d', 'annotation': 'Router 2, Uniswap, Router'}, 'taker': {'address': '0x7650a5ec2fc9d1457e6c0899c52e5cc31d59df50', 'annotation': None}, 'protocol': 'Uniswap v2', 'smartContract': {'address': {'address': '0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852', 'annotation': None}, 'contractType': 'DEX'}}, {'block': {'height': 12687441, 'timestamp': {'iso8601': '2021-06-23T01:12:58Z'}}, 'transaction': {'hash': '0x3be551cd6fd0785801796a9757b08528fa44069167550ad25a46b8c433a7ea49'}, 'tradeIndex': '4', 'buyCurrency': {'symbol': 'USDT', 'address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'buyAmount': 2375.91, 'sellCurrency': {'symbol': 'WETH', 'address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'}, 'sellAmount': 1.2043466420594777, 'maker': {'address': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d', 'annotation': 'Router 2, Uniswap, Router'}, 'taker': {'address': '0xdfea03ed1ec53116cd6ea45373cbb6e8823ef59d', 'annotation': None}, 'protocol': 'Uniswap v2', 'smartContract': {'address': {'address': '0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852', 'annotation': None}, 'contractType': 'DEX'}}, {'block': {'height': 12687439, 'timestamp': {'iso8601': '2021-06-2 ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(result['data']['ethereum'])

# %%
print(df)
# Out:
#                                              dexTrades
# 0    {'block': {'height': 12687442, 'timestamp': {'...
# 1    {'block': {'height': 12687442, 'timestamp': {'...
# 2    {'block': {'height': 12687442, 'timestamp': {'...
# 3    {'block': {'height': 12687441, 'timestamp': {'...
# 4    {'block': {'height': 12687441, 'timestamp': {'...
# ..                                                 ...
# 995  {'block': {'height': 12686397, 'timestamp': {'...
# 996  {'block': {'height': 12686397, 'timestamp': {'...
# 997  {'block': {'height': 12686396, 'timestamp': {'...
# 998  {'block': {'height': 12686394, 'timestamp': {'...
# 999  {'block': {'height': 12686393, 'timestamp': {'...
#
# [1000 rows x 1 columns]

# %%
print(df.shape)
# Out:
# (1000, 1)

# %%
df.dexTrades = df.dexTrades.fillna({i: {} for i in df.index})

# %%
df = df.join(pd.json_normalize(df.dexTrades))

# %%
df.drop(columns=['dexTrades'], inplace=True)

# %%
print(df)
# Out:
#     tradeIndex     buyAmount  sellAmount    protocol  block.height  \
# 0            7    411.989535    0.215093  Uniswap v2      12687442
# 1           21  47993.361914   24.318619  Uniswap v2      12687442
# 2           11   9598.672382    4.855868  Uniswap v2      12687442
# 3            4   1000.000000    0.506917  Uniswap v2      12687441
# 4            4   2375.910000    1.204347  Uniswap v2      12687441
# ..         ...           ...         ...         ...           ...
# 995          8     58.826295    0.030752  Uniswap v2      12686397
# 996          4   8700.000000    4.548285  Uniswap v2      12686397
# 997          4    690.000000    0.360755  Uniswap v2      12686396
# 998          6    560.195900    0.292893  Uniswap v2      12686394
# 999          4   1000.000000    0.522847  Uniswap v2      12686393
#
#     block.timestamp.iso8601  \
# 0      2021-06-23T01:13:05Z
# 1      2021-06-23T01:13:05Z
# 2      2021-06-23T01:13:05Z
# 3      2021-06-23T01:12:58Z
# 4      2021-06-23T01:12:58Z
# ..                      ...
# 995    2021-06-22T21:13:48Z
# 996    2021-06-22T21:13:48Z
# 997    2021-06-22T21:13:46Z
# 998    2021-06-22T21:13:17Z
# 999    2021-06-22T21:13:03Z
#
#                                       transaction.hash buyCurrency.symbol  \
# 0    0xe32ca6362a052dbc3e4390cd0ba4f38dd63a24c2af5c...               USDT
# 1    0xacd255094cf80150742d34bc2169850da41be037c612...               USDT
# 2    0xacd255094cf80150742d34bc2169850da41be037c612...               USDT
# 3    0xe48576a79adfeb822a27db0a4c71e3720595dd6f44e4...               USDT
# 4    0x3be551cd6fd0785801796a9757b08528fa4406916755...               USDT
# ..                                                 ...                ...
# 995  0xeef97cc3aade8b012d8bd4504c10ec331de87eda98cb...               USDT
# 996  0xdc081461619bd25bed0c01540a3c849ebd433707e94f...               USDT
# 997  0x86ea6c5ebc0c75bd040cccb3fa10d9b6b79ca080a1a0...               USDT
# 998  0x6abdc6a7a9ee94ecdac8e15f0e1c7a4b73f4c1f6eaee...               USDT
# 999  0xa0386928bc8a62ed1790f6c5cec81ba5194ff9d71519...               USDT
#
#                             buyCurrency.address sellCurrency.symbol  \
# 0    0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# 1    0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# 2    0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# 3    0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# 4    0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# ..                                          ...                 ...
# 995  0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# 996  0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# 997  0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# 998  0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
# 999  0xdac17f958d2ee523a2206206994597c13d831ec7                WETH
#
#                            sellCurrency.address  \
# 0    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                                          ...
# 995  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 996  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 997  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 998  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 999  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                                   maker.address           maker.annotation  \
# 0    0x0000000000007f150bd6f54c40a34d7c3d5e9f56                       None
# 1    0xfd3dfb524b2da40c8a6d703c62be36b5d8540626                       None
# 2    0xfd3dfb524b2da40c8a6d703c62be36b5d8540626                       None
# 3    0x7a250d5630b4cf539739df2c5dacb4c659f2488d  Router 2, Uniswap, Router
# 4    0x7a250d5630b4cf539739df2c5dacb4c659f2488d  Router 2, Uniswap, Router
# ..                                          ...                        ...
# 995  0x7a250d5630b4cf539739df2c5dacb4c659f2488d  Router 2, Uniswap, Router
# 996  0x7a250d5630b4cf539739df2c5dacb4c659f2488d  Router 2, Uniswap, Router
# 997  0x7a250d5630b4cf539739df2c5dacb4c659f2488d  Router 2, Uniswap, Router
# 998  0x7a250d5630b4cf539739df2c5dacb4c659f2488d  Router 2, Uniswap, Router
# 999  0x7a250d5630b4cf539739df2c5dacb4c659f2488d  Router 2, Uniswap, Router
#
#                                   taker.address           taker.annotation  \
# 0    0xdfee68a9adb981cd08699891a11cabe10f25ec44                       None
# 1    0xfd3dfb524b2da40c8a6d703c62be36b5d8540626                       None
# 2    0xfd3dfb524b2da40c8a6d703c62be36b5d8540626                       None
# 3    0x7650a5ec2fc9d1457e6c0899c52e5cc31d59df50                       None
# 4    0xdfea03ed1ec53116cd6ea45373cbb6e8823ef59d                       None
# ..                                          ...                        ...
# 995  0x7a250d5630b4cf539739df2c5dacb4c659f2488d  Router 2, Uniswap, Router
# 996  0x1f964ff83c54ce447adae5cb93f9ec17018bf55b                       None
# 997  0xc60c479f3cc66f1654a4113f4949c98ce77a9995                       None
# 998  0x904144473fde753dc0729608cfeea6f4a8b275e6      AMM Wrapper, Tokenlon
# 999  0x4214290310264a27b0ba8cff02b4c592d0234aa1                       None
#
#                   smartContract.address.address  \
# 0    0x60fa657cec375e8208e23f50c4ec03167f7c6076
# 1    0x06da0fd433c1a5d7a4faa01111c044910a184553
# 2    0x74c99f3f5331676f6aec2756e1f39b4fc029a83e
# 3    0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# 4    0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# ..                                          ...
# 995  0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# 996  0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# 997  0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# 998  0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# 999  0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
#
#     smartContract.address.annotation smartContract.contractType
# 0                               None                        DEX
# 1                               None                        DEX
# 2                               None                        DEX
# 3                               None                        DEX
# 4                               None                        DEX
# ..                               ...                        ...
# 995                             None                        DEX
# 996                             None                        DEX
# 997                             None                        DEX
# 998                             None                        DEX
# 999                             None                        DEX
#
# [1000 rows x 18 columns]

# %%
import matplotlib as plt
import matplotlib.pyplot as plt

df['RollingBuy1'] = df['buyAmount'].rolling(window = 50).mean()
df['RollingBuy2'] = df['buyAmount'].rolling(window = 150).mean()
plt.plot(df['RollingBuy1'])
plt.plot(df['RollingBuy2'])

# %%
df['RollingSell1'] = df['sellAmount'].rolling(window=50).mean()
df['RollingSell2'] = df['sellAmount'].rolling(window = 150).mean()

plt.plot(df['RollingSell1'])
plt.plot(df['RollingSell2'])

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/singularity/Library/Python/3.8/lib/python/site-packages (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/singularity/Library/Python/3.8/lib/python/site-packages (from requests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/singularity/Library/Python/3.8/lib/python/site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/singularity/Library/Python/3.8/lib/python/site-packages (from requests) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
api_key = "ACCWmH4be2fv5"
#link = "https://api.bloxy.info/dex/pair_stat?key=ACCWmH4be2fv5&format=structure"
#the above link is 100 requests
#link = "https://api.bloxy.info/dex/pair_stat?limit=1000&key=ACCWmH4be2fv5&format=structure"
#the above link is 1000 pieces of data

#link = "https://api.bloxy.info/dex/pair_stat?limit=1000&from_date=100+days+ago&key=ACCWmH4be2fv5&format=structure"
#so the above links are Statistics of DEX token pairs
#now statistics of token dex trades
#link = "https://api.bloxy.info/dex/token_stat?token=0x1f9840a85d5af5bf1d1762f925bdaddc4201f984&limit=1000&from_date=180+days+ago&key=ACCWmH4be2fv5&format=structure"
#so the above is for all uni transactions on the pool. 
#New link, now all trades
#link = "https://api.bloxy.info/dex/trades?token=0x1f9840a85d5af5bf1d1762f925bdaddc4201f984&key=ACCWmH4be2fv5&format=structure"
link = 'https://api.bloxy.info/dex/trades?protocol=Uniswap+v2&token=0x1f9840a85d5af5bf1d1762f925bdaddc4201f984&limit=1500&from_date=2021-01-01&till_date=2021-06-22&key=ACCWmH4be2fv5&format=structure'
#new api, Uniswap Protocol, data from 01-01-2021 to 22-06-2021
#this is the UNI protocol, all UNI token buys and sells
#filter_1 = df[(df['buySymbol'] == 'UNI') & (df['sellSymbol'] == 'WETH')]
#filter_2 = df[(df['buySymbol'] == 'WETH') & (df['sellSymbol'] == 'UNI')]
response = requests.get(link)
x = response.json()
df = pd.DataFrame(x)
filter_1 = df[(df['buySymbol'] == 'UNI') & (df['sellSymbol'] == 'WETH')]
filter_2 = df[(df['buySymbol'] == 'WETH') & (df['sellSymbol'] == 'UNI')]
#filtered_data = df[(df['buyToken'] == 'WETH') & (df['sellToken'] == 'UNI')]
#print(filter_1)
#print(filter_2)
print(filter_1.shape)
print(filter_2.shape)






#print(df)

#now I have two methods of querying, one is through Bitquery and the other is through Bloxy.
#the data from the above link is for the previous 30 days
# I have queried about 500 bits of data
#the major limitation with bloxy is that I only have 50 requests available, since the account is on a trial period right now.
# Out:
# (723, 29)
# 1499  2021-06-21  2021-06-21T04:00:00.000+00:00  2164.705926        15881
#
#                     sell_price_time   sell_price market_data2.currency_id  \
# 0     2021-06-22T22:00:00.000+00:00  1874.317793                    15881
# 1     2021-06-22T22:00:00.000+00:00  1874.317793                    15881
# 3     2021-06-22T22:00:00.000+00:00  1874.317793                    15881
# 6     2021-06-22T22:00:00.000+00:00  1874.317793                    15881
# 16    2021-06-22T22:00:00.000+00:00  1874.317793                    15881
# ...                             ...          ...                      ...
# 1486  2021-06-21T05:00:00.000+00:00    19.437429                   533286
# 1489  2021-06-21T05:00:00.000+00:00    19.437429                   533286
# 1491  2021-06-21T05:00:00.000+00:00    19.437429                   533286
# 1497  2021-06-21T04:00:00.000+00:00    20.006039                   533286
# 1499  2021-06-21T04:00:00.000+00:00    20.006039                   533286
#
#       amountBuyInCurrency  amountSellInCurrency
# 0               98.228410             98.015656
# 1               17.782409             17.743530
# 3             3270.811636           3263.940740
# 6              113.927813            113.698616
# 16             572.392036            569.669395
# ...                   ...                   ...
# 1486         12193.851183          12285.771643
# 1489         11904.261605          11996.146780
# 1491         10252.866163          10335.301359
# 1497          6852.872189           6907.541535
# 1499             2.124307              2.142354
#
# [1258 rows x 29 columns]

# %%
result['RollingBuy1'] = result['buy_price'].rolling(window = 50).mean()
result['RollingBuy2'] = result['buy_price'].rolling(window = 200).mean()

plt.plot(result['RollingBuy1'])
plt.plot(result['RollingBuy2'])

# %%
plt.plot(df['amountBuy'])

# %%
#Volume Analysis
api_1 = 'ACCWmH4be2fv5'
link_1 = 'https://api.bloxy.info/dex/token_stat?token=0x1f9840a85d5af5bf1d1762f925bdaddc4201f984&limit=1500&from_date=2021-01-01&key=ACCWmH4be2fv5&format=structure'
response_1 = requests.get(link_1)
x_1 = response_1.json()
df_1 = pd.DataFrame(x_1)
filteration_1 = df_1[df_1['protocol'] == 'Uniswap v2']
filteration_2 = filteration_1[filteration_1['symbol'] == 'WETH']
print(filteration_2)
# Out:
#                                  smart_contract    protocol symbol  \
# 0    0xd3d2e2692501a5c9ca623199d38826e513033a17  Uniswap v2   WETH
# 1    0xd3d2e2692501a5c9ca623199d38826e513033a17  Uniswap v2   WETH
# 2    0xdafd66636e2561b0284edde37e42d192f2844d40  Uniswap v2   WETH
# 3    0xdafd66636e2561b0284edde37e42d192f2844d40  Uniswap v2   WETH
# 30   0xd360131b77ead72f1f23fb185b4896fe01dc8cb5  Uniswap v2   WETH
# 31   0xd360131b77ead72f1f23fb185b4896fe01dc8cb5  Uniswap v2   WETH
# 137  0xa6e0e7914918b9fc8460d3f97071e9520ce1f3a8  Uniswap v2   WETH
# 149  0xa6e0e7914918b9fc8460d3f97071e9520ce1f3a8  Uniswap v2   WETH
# 209  0xccd8c402a4b91ab59a50d30dbbdb29f1faec411d  Uniswap v2   WETH
# 219  0xccd8c402a4b91ab59a50d30dbbdb29f1faec411d  Uniswap v2   WETH
# 258  0x6579d38b915fbdfa67420142e5eb4f13b0cda666  Uniswap v2   WETH
# 261  0xa743ace7dbb47115521bf8e159408771173f1098  Uniswap v2   WETH
# 262  0x6579d38b915fbdfa67420142e5eb4f13b0cda666  Uniswap v2   WETH
# 281  0x0042204c08aa1ab551a0f9ebf2f0c3b14461d661  Uniswap v2   WETH
# 284  0x0a15b638b313b8e3077e8e5d496e7be653a4d691  Uniswap v2   WETH
# 287  0x0042204c08aa1ab551a0f9ebf2f0c3b14461d661  Uniswap v2   WETH
# 291  0x0a15b638b313b8e3077e8e5d496e7be653a4d691  Uniswap v2   WETH
# 300  0xa743ace7dbb47115521bf8e159408771173f1098  Uniswap v2   WETH
# 361  0x54f0860d6951b389a7656b6b3915d5bd2270ca0b  Uniswap v2   WETH
# 371  0x54f0860d6951b389a7656b6b3915d5bd2270ca0b  Uniswap v2   WETH
# 434  0x9d7d2e2c67ef21a0d3ee5b309d417d0ff601392f  Uniswap v2   WETH
# 446  0x9d7d2e2c67ef21a0d3ee5b309d417d0ff601392f  Uniswap v2   WETH
# 617  0xa8b3957eaa05ba3d21298706aeb7c286b4e1ed90  Uniswap v2   WETH
# 643  0xa8b3957eaa05ba3d21298706aeb7c286b4e1ed90  Uniswap v2   WETH
# 682  0x1ac57db37c04844221b4c5cd757aa950c78de01d  Uniswap v2   WETH
# 714  0x1ac57db37c04844221b4c5cd757aa950c78de01d  Uniswap v2   WETH
# 823  0x56b05bf6c880ecd311d1bf158ac92bf91a1560f7  Uniswap v2   WETH
# 857  0x56b05bf6c880ecd311d1bf158ac92bf91a1560f7  Uniswap v2   WETH
# 870  0xba6ee5e49bd8e13a93d9cf8b1537cc111bdcd0af  Uniswap v2   WETH
# 904  0xba6ee5e49bd8e13a93d9cf8b1537cc111bdcd0af  Uniswap v2   WETH
#
#                                           token        volume  trades
# 0    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.224410e+08   88714
# 1    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.211474e+08  108771
# 2    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.702099e+07   18018
# 3    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.696719e+07   18169
# 30   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.181238e+05    1480
# 31   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.145540e+05    1482
# 137  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  7.351540e+03      48
# 149  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  5.522621e+03      48
# 209  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.922441e+03      77
# 219  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.714262e+03      79
# 258  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.166928e+03      38
# 261  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.154452e+03      51
# 262  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.153931e+03      37
# 281  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  1.011686e+03      61
# 284  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  9.908141e+02      74
# 287  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  9.663452e+02      65
# 291  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  9.083961e+02      73
# 300  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  8.560938e+02      52
# 361  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  4.847722e+02      36
# 371  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  4.391446e+02      41
# 434  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  3.012631e+02     211
# 446  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  2.764517e+02     142
# 617  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  6.985250e+01      10
# 643  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  5.403806e+01      10
# 682  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  3.795543e+01       8
# 714  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  2.679072e+01       5
# 823  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  9.090470e+00       5
# 857  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  5.215630e+00       3
# 870  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  4.449206e+00       1
# 904  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  2.981845e+00       3

# %%
#the above data is cummulative of the trade volumes obtained by the Statistics of Token DEX Trades at DEX method. I used this instead of 
# Statistics of token pairs trades at DEX.
